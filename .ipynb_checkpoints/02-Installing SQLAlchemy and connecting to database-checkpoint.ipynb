# %%
from sqlalchemy import  create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 
# engine = create_engine("mysql+pymysql://root:pass@localhost/mydb")

# Connecting to MySQL server at 23.92.23.113 using mysql-python DBAPI 
# engine = create_engine("mysql+mysqldb://root:pass@23.92.23.113/mydb")

# Connecting to PostgreSQL server at localhost using psycopg2 DBAPI 
engine = create_engine("postgresql+psycopg2://root:pass@localhost/mydb")

# Connecting to Oracle server at localhost using cx-Oracle DBAPI
# engine = create_engine("oracle+cx_oracle://root:pass@localhost/mydb")

# Connecting to MSSQL server at localhost using PyODBC DBAPI
# engine = create_engine("oracle+pyodbc://root:pass@localhost/mydb")

# %%
# from sqlalchemy import  create_engine

# engine = create_engine('sqlite:///sqlite3.db') # using relative path
# engine = create_engine('sqlite:////path/to/sqlite3.db') # using absolute path

# %%
from sqlalchemy import create_engine

engine = create_engine("postgres+psycopg2://postgres:pass@localhost/sqlalchemy_tuts")
engine.connect()

print(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2220         try:
# -> 2221             return fn()
#    2222         except dialect.dbapi.Error as e:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     355         """
# --> 356         return _ConnectionFairy._checkout(self)
#     357
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     810         if not fairy:
# --> 811             fairy = _ConnectionRecord.checkout(pool)
#     812
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     542     def checkout(cls, pool):
# --> 543         rec = pool._do_get()
#     544         try:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1238                 with util.safe_reraise():
# -> 1239                     self._dec_overflow()
#    1240         else:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1235             try:
# -> 1236                 return self._create_connection()
#    1237             except:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     360
# --> 361         return _ConnectionRecord(self)
#     362
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     487         if connect:
# --> 488             self.__connect(first_connect_check=True)
#     489         self.finalize_callback = deque()
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     689             self.starttime = time.time()
# --> 690             connection = pool._invoke_creator(self)
#     691             pool.logger.debug("Created new connection %r", connection)
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-1c665b21b739> in <module>
#       2
#       3 engine = create_engine("postgres+psycopg2://postgres:pass@localhost/sqlalchemy_tuts")
# ----> 4 engine.connect()
#       5
#       6 print(engine)
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2162         """
#    2163
# -> 2164         return self._connection_cls(self, **kwargs)
#    2165
#    2166     def contextual_connect(self, close_with_result=False, **kwargs):
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2250         """
#    2251         return self._wrap_pool_connect(
# -> 2252             self.pool.unique_connection, _connection
#    2253         )
#    2254
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2223             if connection is None:
#    2224                 Connection._handle_dbapi_exception_noconnection(
# -> 2225                     e, dialect, self
#    2226                 )
#    2227             else:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1520             util.raise_from_cause(newraise, exc_info)
#    1521         elif should_wrap:
# -> 1522             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1523         else:
#    1524             util.reraise(*exc_info)
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2219         dialect = self.dialect
#    2220         try:
# -> 2221             return fn()
#    2222         except dialect.dbapi.Error as e:
#    2223             if connection is None:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     354
#     355         """
# --> 356         return _ConnectionFairy._checkout(self)
#     357
#     358     def _create_connection(self):
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     809     def _checkout(cls, pool, threadconns=None, fairy=None):
#     810         if not fairy:
# --> 811             fairy = _ConnectionRecord.checkout(pool)
#     812
#     813             fairy._pool = pool
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     541     @classmethod
#     542     def checkout(cls, pool):
# --> 543         rec = pool._do_get()
#     544         try:
#     545             dbapi_connection = rec.get_connection()
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1237             except:
#    1238                 with util.safe_reraise():
# -> 1239                     self._dec_overflow()
#    1240         else:
#    1241             return self._do_get()
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             self._exc_info = None  # remove potential circular references
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#      69             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     275         if value.__traceback__ is not tb:
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#     279
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1234         if self._inc_overflow():
#    1235             try:
# -> 1236                 return self._create_connection()
#    1237             except:
#    1238                 with util.safe_reraise():
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     359         """Called by subclasses to create a new ConnectionRecord."""
#     360
# --> 361         return _ConnectionRecord(self)
#     362
#     363     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     486         self.__pool = pool
#     487         if connect:
# --> 488             self.__connect(first_connect_check=True)
#     489         self.finalize_callback = deque()
#     490
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     688         try:
#     689             self.starttime = time.time()
# --> 690             connection = pool._invoke_creator(self)
#     691             pool.logger.debug("Created new connection %r", connection)
#     692             self.connection = connection
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     435
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#     439     def create_connect_args(self, url):
#
# ~/Desktop/other_github_dirs/sqlalchemy/.venv/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#  (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgres+psycopg2://postgres:pass@localhost/sqlalchemy_tuts", 
    echo=True, pool_size=6, max_overflow=10, encoding='latin1'
)

engine.connect()

print(engine)
# Out:
# 2018-07-07 18:39:14,402 INFO sqlalchemy.engine.base.Engine select version()
# 2018-07-07 18:39:14,403 INFO sqlalchemy.engine.base.Engine {}
# 2018-07-07 18:39:14,408 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2018-07-07 18:39:14,410 INFO sqlalchemy.engine.base.Engine {}
# 2018-07-07 18:39:14,413 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-07-07 18:39:14,416 INFO sqlalchemy.engine.base.Engine {}
# 2018-07-07 18:39:14,419 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-07-07 18:39:14,421 INFO sqlalchemy.engine.base.Engine {}
# 2018-07-07 18:39:14,423 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2018-07-07 18:39:14,424 INFO sqlalchemy.engine.base.Engine {}
# Engine(postgres+psycopg2://postgres:***@localhost/sqlalchemy_tuts)
